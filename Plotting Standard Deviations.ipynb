# %%
# These lines import the Numpy modules.
import numpy as np
from datascience import *
from pandas import *
import glob


# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)
import os

# %%
data = Table.read_table('all_with_zscores.csv')
data
# Out:
# Date      | Unnamed: 1 |  Altitude |  Altitude_zscore |  Altitude_zscore_zscore |  CH4_dry |  CH4_dry_zscore |  CH4_dry_zscore_zscore |  Latitude |  Latitude_zscore |  Latitude_zscore_zscore |  Longitude |  Longitude_zscore |  Longitude_zscore_zscore |  TIME_GPS |  TIME_GPS_zscore |  TIME_GPS_zscore_zscore
# 5/24/2013 | 8067       | -17.5113  | -0.229728        | nan                     | 2.10622  | 6.44518         | nan                    | 37.4044   | -0.432376        | nan                     | -122.045   | -0.349073         | nan                      | 73392     | -1.69744         | nan
# 5/24/2013 | 8068       | 281.827   | 4.01153          | nan                     | 1.98568  | 1.81388         | nan                    | 37.4379   | 3.55662          | nan                     | -122.054   | -3.52052          | nan                      | 73804     | 1.64437          | nan
# ...

# %%
data_5242013 = data.where(data.column('Date')=='5/24/2013')
data_5242013.hist(6, bins=10, normed=True, align='mid')
data_5242013.hist(5, bins=10,normed=True, align='mid')
